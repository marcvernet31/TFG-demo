# %%
import pandas as pd

# %%
catalog = pd.read_csv("../data/catalegBCN_2022-02-19_11-16.csv")

# %%
catalog["date_published"]
# Out:
# 0      2017-07-06
# 1      2019-11-15
# 2      2015-11-19
# 3      2015-06-10
# 4      2015-11-19
#           ...
# 517    2017-05-04
# 518    2021-07-21
# 519    2015-11-17
# 520    2020-06-08
# 521    2017-05-04
# Name: date_published, Length: 522, dtype: object

# %%
catalog = catalog[["title_ca", "notes_ca", "organization_parent_name_ca", "organization_name_ca", "date_published", "fuente", "url_busqueda_ca"]]
# Out:
#                                               title_ca  \
# 0    Unitats administratives  de la ciutat de Barce...
# 1    Accessibilitat a la via pública de la ciutat d...
# 2    Descripció de la causalitat dels accidents ges...
# 3    Accidents gestionats per la Guàrdia Urbana a l...
# 4    Persones involucrades en accidents gestionats ...
# ..                                                 ...
# 517  Vies Pedalables "Ciclables" a la ciutat de Bar...
# 518  Xarxa de refugis climàtics a la ciutat de Barc...
# 519  Zones de càrrega i descàrrega  a la ciutat de ...
# 520  Zones d'estacionament Zona BUS de la ciutat de...
# 521                  Zones 30 a la ciutat de Barcelona
#
#                                               notes_ca  \
# 0    Detall de les unitats administratives  de la c...
# 1    Llista geolocalitzada dels paràmetres d'access...
# 2    Llistat de de la causalitat dels accidents ges...
# 3    Llistat dels accidents gestionats per la Guàrd...
# ...

# %%
catalog = catalog.rename(columns={"title_ca":"title", "notes_ca":"description", "url_busqueda_ca":"web_url", "organization_parent_name_ca":"category"})

# %%
catalog.to_csv("../data/catalog_Barcelona.csv")
